# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("raw_data/ml_case_training_data.csv")
hist_data = pd.read_csv("raw_data/ml_case_training_hist_data.csv")
output = pd.read_csv("raw_data/ml_case_training_output.csv")

# %%
data.head()
# Out:
#                                  id                      activity_new  \
# 0  48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1  24011ae4ebbe3035111d65fa7c15bc57                               NaN
# 2  d29c2c54acc38ff3c0614d0a653813dd                               NaN
# 3  764c75f661154dac3a6c254cd082ea7d                               NaN
# 4  bba03439a292a1e166f80264c16191cb                               NaN
#
#    campaign_disc_ele                     channel_sales  cons_12m  \
# 0                NaN  lmkebamcaaclubfxadlmueccxoimlema    309275
# 1                NaN  foosdfpfkusacimwkcsosbicdxkicaua         0
# 2                NaN                               NaN      4660
# 3                NaN  foosdfpfkusacimwkcsosbicdxkicaua       544
# 4                NaN  lmkebamcaaclubfxadlmueccxoimlema      1584
#
#    cons_gas_12m  cons_last_month  date_activ    date_end date_first_activ  \
# 0             0            10025  2012-11-07  2016-11-06              NaN
# ...

# %%
# drop columns with more than 50% null values 
def drop_nulls(df):
    for col in df:
        null_val = df[col].isnull().sum()
        if null_val/len(df) > 0.5:
            print("Removed ", col, "with", null_val/len(df)*100, "% null values")
            df = df.drop(col, axis=1)
    return df

# fill null values for the model
# fill categorical features with most frequest category using mode
# fill integer and float features with mean value
def fill_nulls(df):
    for col in df:
        if df[col].dtypes=="object":
            df[col].fillna(df[col].mode()[0], inplace=True)
        else:
            df[col].fillna(df[col].mean(), inplace=True)
    return df

# %% [markdown]
# # Data cleaning and exploration

# %%
data = drop_nulls(data)
data.head()
# Out:
# Removed  activity_new with 59.30044731610338 % null values
# Removed  campaign_disc_ele with 100.0 % null values
# Removed  date_first_activ with 78.20576540755468 % null values
# Removed  forecast_base_bill_ele with 78.20576540755468 % null values
# Removed  forecast_base_bill_year with 78.20576540755468 % null values
# Removed  forecast_bill_12m with 78.20576540755468 % null values
# Removed  forecast_cons with 78.20576540755468 % null values
#                                  id                     channel_sales  \
# 0  48ada52261e7cf58715202705a0451c9  lmkebamcaaclubfxadlmueccxoimlema
# 1  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 2  d29c2c54acc38ff3c0614d0a653813dd                               NaN
# 3  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 4  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# ...

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(data.corr(), fignum=f.number)
plt.xticks(range(data.shape[1]), data.columns, fontsize=14, rotation=45)
plt.yticks(range(data.shape[1]), data.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.show()

# %%
data = fill_nulls(data)
data.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.609600e+04  1.609600e+04     1.609600e+04       16096.000000
# mean   1.948044e+05  3.191164e+04     1.946154e+04        2370.555949
# std    6.795151e+05  1.775885e+05     8.235676e+04        4035.085664
# min   -1.252760e+05 -3.037000e+03    -9.138600e+04      -16689.260000
# 25%    5.906250e+03  0.000000e+00     0.000000e+00         513.230000
# 50%    1.533250e+04  0.000000e+00     9.010000e+02        1179.160000
# 75%    5.022150e+04  0.000000e+00     4.127000e+03        2692.077500
# max    1.609711e+07  4.188440e+06     4.538720e+06      103801.930000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        16096.000000              16096.000000             16096.000000
# mean          1907.347229                  0.991547                70.309945
# std           5257.364759                  5.140728                79.023251
# ...

# %% [markdown]
# # historical data cleaning and exploration

# %%
hist_data.head()
# Out:
#                                  id  price_date  price_p1_var  price_p2_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01      0.151367           0.0
# 1  038af19179925da21a25619c5a24b745  2015-02-01      0.151367           0.0
# 2  038af19179925da21a25619c5a24b745  2015-03-01      0.151367           0.0
# 3  038af19179925da21a25619c5a24b745  2015-04-01      0.149626           0.0
# 4  038af19179925da21a25619c5a24b745  2015-05-01      0.149626           0.0
#
#    price_p3_var  price_p1_fix  price_p2_fix  price_p3_fix
# 0           0.0     44.266931           0.0           0.0
# 1           0.0     44.266931           0.0           0.0
# 2           0.0     44.266931           0.0           0.0
# 3           0.0     44.266931           0.0           0.0
# 4           0.0     44.266931           0.0           0.0

# %%
hist_data = drop_nulls(hist_data)
hist_data.head()
# Out:
#                                  id  price_date  price_p1_var  price_p2_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01      0.151367           0.0
# 1  038af19179925da21a25619c5a24b745  2015-02-01      0.151367           0.0
# 2  038af19179925da21a25619c5a24b745  2015-03-01      0.151367           0.0
# 3  038af19179925da21a25619c5a24b745  2015-04-01      0.149626           0.0
# 4  038af19179925da21a25619c5a24b745  2015-05-01      0.149626           0.0
#
#    price_p3_var  price_p1_fix  price_p2_fix  price_p3_fix
# 0           0.0     44.266931           0.0           0.0
# 1           0.0     44.266931           0.0           0.0
# 2           0.0     44.266931           0.0           0.0
# 3           0.0     44.266931           0.0           0.0
# 4           0.0     44.266931           0.0           0.0

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(hist_data.corr(), fignum=f.number)
plt.xticks(range(hist_data.shape[1]), hist_data.columns, fontsize=14, rotation=45)
plt.yticks(range(hist_data.shape[1]), hist_data.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.show()

# %%
hist_data = fill_nulls(hist_data)
hist_data.describe()
# Out:
#         price_p1_var   price_p2_var   price_p3_var   price_p1_fix  \
# count  193002.000000  193002.000000  193002.000000  193002.000000
# mean        0.140991       0.054412       0.030712      43.325546
# std         0.025029       0.049857       0.036207       5.418773
# min         0.000000       0.000000       0.000000      -0.177779
# 25%         0.125976       0.000000       0.000000      40.728885
# 50%         0.145859       0.085100       0.000000      44.266930
# 75%         0.151635       0.101673       0.072558      44.444710
# max         0.280700       0.229788       0.114102      59.444710
#
#         price_p2_fix   price_p3_fix
# count  193002.000000  193002.000000
# mean       10.698201       6.455436
# std        12.810704       7.754831
# min        -0.097752      -0.065172
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%        24.339581      16.226389
# max        36.490692      17.458221

# %% [markdown]
# # Explore output labels

# %%
output.head()
# Out:
#                                  id  churn
# 0  48ada52261e7cf58715202705a0451c9      0
# 1  24011ae4ebbe3035111d65fa7c15bc57      1
# 2  d29c2c54acc38ff3c0614d0a653813dd      0
# 3  764c75f661154dac3a6c254cd082ea7d      0
# 4  bba03439a292a1e166f80264c16191cb      0

# %%
sns.countplot(output['churn'])

# %%
output.describe()
# Out:
#               churn
# count  16096.000000
# mean       0.099093
# std        0.298796
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
data = pd.merge(data, output, how="left", left_on="id", right_on="id")
data.to_csv('processed_data/data.csv')
hist_data.to_csv('processed_data/hist_data.csv')

# %% [markdown]
# ##  feature engineering based on the corelationship will be done in the next stage
